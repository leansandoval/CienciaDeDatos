# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report # métrica de evaluación
from sklearn import metrics

# %% [markdown]
# # Análisis Exploratorio

# %%
df_nasa = pd.read_csv('https://raw.githubusercontent.com/pokengineer/DataScience/main/datasets/asteroids_nasa.csv')
df_nasa.head(5)
# Out:
#    Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0           3703080  3703080                21.6            0.127220
# 1           3723955  3723955                21.3            0.146068
# 2           2446862  2446862                20.3            0.231502
# 3           3092506  3092506                27.4            0.008801
# 4           3514799  3514799                21.6            0.127220
#
#    Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# 0            0.284472         127.219879         284.472297
# 1            0.326618         146.067964         326.617897
# 2            0.517654         231.502122         517.654482
# 3            0.019681           8.801465          19.680675
# 4            0.284472         127.219879         284.472297
#
#    Est Dia in Miles(min)  Est Dia in Miles(max)  Est Dia in Feet(min)  ...  \
# 0               0.079051               0.176763            417.388066  ...
# 1               0.090762               0.202951            479.225620  ...
# 2               0.143849               0.321655            759.521423  ...
# 3               0.005469               0.012229             28.876199  ...
# 4               0.079051               0.176763            417.388066  ...
#
#    Asc Node Longitude Orbital Period  Perihelion Distance  Perihelion Arg  \
# 0          314.373913     609.599786             0.808259       57.257470
# 1          136.717242     425.869294             0.718200      313.091975
# 2          259.475979     643.580228             0.950791      248.415038
# 3           57.173266     514.082140             0.983902       18.707701
# 4           84.629307     495.597821             0.967687      158.263596
#
#    Aphelion Dist  Perihelion Time  Mean Anomaly  Mean Motion  Equinox  \
# 0       2.005764     2.458162e+06    264.837533     0.590551    J2000
# 1       1.497352     2.457795e+06    173.741112     0.845330    J2000
# 2       1.966857     2.458120e+06    292.893654     0.559371    J2000
# 3       1.527904     2.457902e+06     68.741007     0.700277    J2000
# 4       1.483543     2.457814e+06    135.142133     0.726395    J2000
#
#    Hazardous
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#
# [5 rows x 40 columns]

# %%
# verificamos los tipos de datos
df_nasa.dtypes
# Out:
# Neo Reference ID                  int64
# Name                              int64
# Absolute Magnitude              float64
# Est Dia in KM(min)              float64
# Est Dia in KM(max)              float64
# Est Dia in M(min)               float64
# Est Dia in M(max)               float64
# Est Dia in Miles(min)           float64
# Est Dia in Miles(max)           float64
# Est Dia in Feet(min)            float64
# Est Dia in Feet(max)            float64
# Close Approach Date              object
# Epoch Date Close Approach         int64
# Relative Velocity km per sec    float64
# Relative Velocity km per hr     float64
# Miles per hour                  float64
# Miss Dist.(Astronomical)        float64
# Miss Dist.(lunar)               float64
# Miss Dist.(kilometers)          float64
# Miss Dist.(miles)               float64
# Orbiting Body                    object
# Orbit ID                          int64
# Orbit Determination Date         object
# Orbit Uncertainity                int64
# Minimum Orbit Intersection      float64
# Jupiter Tisserand Invariant     float64
# Epoch Osculation                float64
# Eccentricity                    float64
# Semi Major Axis                 float64
# Inclination                     float64
# Asc Node Longitude              float64
# Orbital Period                  float64
# Perihelion Distance             float64
# Perihelion Arg                  float64
# Aphelion Dist                   float64
# Perihelion Time                 float64
# Mean Anomaly                    float64
# Mean Motion                     float64
# Equinox                          object
# Hazardous                          bool
# dtype: object

# %%
print("Tamaño del dataframe : {}".format(df_nasa.shape))
# Out:
# Tamaño del dataframe : (4687, 40)

# %%
# Verificamos si hay valores nulos para imputar
df_nasa.isnull().sum()
# Out:
# Neo Reference ID                0
# Name                            0
# Absolute Magnitude              0
# Est Dia in KM(min)              0
# Est Dia in KM(max)              0
# Est Dia in M(min)               0
# Est Dia in M(max)               0
# Est Dia in Miles(min)           0
# Est Dia in Miles(max)           0
# Est Dia in Feet(min)            0
# Est Dia in Feet(max)            0
# Close Approach Date             0
# Epoch Date Close Approach       0
# Relative Velocity km per sec    0
# Relative Velocity km per hr     0
# Miles per hour                  0
# Miss Dist.(Astronomical)        0
# Miss Dist.(lunar)               0
# Miss Dist.(kilometers)          0
# Miss Dist.(miles)               0
# Orbiting Body                   0
# Orbit ID                        0
# Orbit Determination Date        0
# Orbit Uncertainity              0
# Minimum Orbit Intersection      0
# Jupiter Tisserand Invariant     0
# Epoch Osculation                0
# Eccentricity                    0
# Semi Major Axis                 0
# Inclination                     0
# Asc Node Longitude              0
# Orbital Period                  0
# Perihelion Distance             0
# Perihelion Arg                  0
# Aphelion Dist                   0
# Perihelion Time                 0
# Mean Anomaly                    0
# Mean Motion                     0
# Equinox                         0
# Hazardous                       0
# dtype: int64

# %%
# Analisis de la distribución de la variable target "Hazardous"
print( df_nasa.Hazardous.value_counts() )
sns.countplot(x='Hazardous', data=df_nasa, hue='Hazardous', legend=False)
# Out:
# Hazardous
# False    3932
# True      755
# Name: count, dtype: int64
# <Axes: xlabel='Hazardous', ylabel='count'>

# %% [markdown]
# # Correlación de Variables

# %%
plt.figure(figsize=(14,7))
sns.heatmap(df_nasa.drop(['Close Approach Date','Orbiting Body','Orbit Determination Date','Equinox'],axis=1).corr(), vmax=.7, cmap ='Blues', fmt=".2f")
# Out:
# <Axes: >

# %%
df_nasa_corr = df_nasa.drop(['Close Approach Date','Orbiting Body','Orbit Determination Date','Equinox'],axis=1).corr()[["Hazardous"]]*100 # lo pasamos a porcentajes
df_nasa_corr = df_nasa_corr.drop("Hazardous", axis=0) # eliminamos la variable target
df_nasa_corr = abs(df_nasa_corr) # nos interesa el valor absouluto
df_nasa_corr = df_nasa_corr.sort_values(["Hazardous"], ascending=False) # ordenamos en forma descendente
df_nasa_corr
# Out:
#                               Hazardous
# Orbit Uncertainity            32.872134
# Absolute Magnitude            32.552193
# Minimum Orbit Intersection    28.894902
# Name                          26.902814
# Neo Reference ID              26.902814
# Orbit ID                      24.736904
# Perihelion Distance           20.702693
# Relative Velocity km per sec  19.197018
# Miles per hour                19.197018
# Relative Velocity km per hr   19.197018
# Eccentricity                  18.326913
# Est Dia in Miles(max)         13.242435
# Est Dia in M(min)             13.242435
# Est Dia in Feet(max)          13.242435
# Est Dia in Feet(min)          13.242435
# Est Dia in M(max)             13.242435
# Est Dia in KM(max)            13.242435
# Est Dia in KM(min)            13.242435
# Est Dia in Miles(min)         13.242435
# Epoch Date Close Approach      7.902013
# Mean Anomaly                   5.416363
# Epoch Osculation               4.094036
# Aphelion Dist                  4.080019
# Perihelion Time                3.811336
# Miss Dist.(lunar)              3.240743
# Miss Dist.(kilometers)         3.240743
# Miss Dist.(miles)              3.240743
# Miss Dist.(Astronomical)       3.240742
# Asc Node Longitude             1.753648
# Mean Motion                    1.302780
# Orbital Period                 1.116815
# Semi Major Axis                1.077028
# Inclination                    0.960687
# Perihelion Arg                 0.386521
# Jupiter Tisserand Invariant    0.340394

# %% [markdown]
# # Seleccionamos las variables que vamos a utilizar y hacemos el Split

# %%
# dropeo ['Orbiting Body','Equinox'] porque en todos los casos es earth y J2000
df_nasa.drop(['Orbiting Body','Equinox'],axis=1, inplace=True)

# %%
df_nasa.columns
# Out:
# Index(['Neo Reference ID', 'Name', 'Absolute Magnitude', 'Est Dia in KM(min)',
#        'Est Dia in KM(max)', 'Est Dia in M(min)', 'Est Dia in M(max)',
#        'Est Dia in Miles(min)', 'Est Dia in Miles(max)',
#        'Est Dia in Feet(min)', 'Est Dia in Feet(max)', 'Close Approach Date',
#        'Epoch Date Close Approach', 'Relative Velocity km per sec',
#        'Relative Velocity km per hr', 'Miles per hour',
#        'Miss Dist.(Astronomical)', 'Miss Dist.(lunar)',
#        'Miss Dist.(kilometers)', 'Miss Dist.(miles)', 'Orbit ID',
#        'Orbit Determination Date', 'Orbit Uncertainity',
#        'Minimum Orbit Intersection', 'Jupiter Tisserand Invariant',
#        'Epoch Osculation', 'Eccentricity', 'Semi Major Axis', 'Inclination',
#        'Asc Node Longitude', 'Orbital Period', 'Perihelion Distance',
#        'Perihelion Arg', 'Aphelion Dist', 'Perihelion Time', 'Mean Anomaly',
#        'Mean Motion', 'Hazardous'],
#       dtype='object')

# %%
df = df_nasa.drop(['Close Approach Date','Orbit Determination Date'],axis=1)
X_nasa = df.drop("Hazardous",axis=1)
y_nasa = df["Hazardous"]
X_nasa.head()
# Out:
#    Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0           3703080  3703080                21.6            0.127220
# 1           3723955  3723955                21.3            0.146068
# 2           2446862  2446862                20.3            0.231502
# 3           3092506  3092506                27.4            0.008801
# 4           3514799  3514799                21.6            0.127220
#
#    Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# 0            0.284472         127.219879         284.472297
# 1            0.326618         146.067964         326.617897
# 2            0.517654         231.502122         517.654482
# 3            0.019681           8.801465          19.680675
# 4            0.284472         127.219879         284.472297
#
#    Est Dia in Miles(min)  Est Dia in Miles(max)  Est Dia in Feet(min)  ...  \
# 0               0.079051               0.176763            417.388066  ...
# 1               0.090762               0.202951            479.225620  ...
# 2               0.143849               0.321655            759.521423  ...
# 3               0.005469               0.012229             28.876199  ...
# 4               0.079051               0.176763            417.388066  ...
#
#    Semi Major Axis  Inclination  Asc Node Longitude  Orbital Period  \
# 0         1.407011     6.025981          314.373913      609.599786
# 1         1.107776    28.412996          136.717242      425.869294
# 2         1.458824     4.237961          259.475979      643.580228
# 3         1.255903     7.905894           57.173266      514.082140
# 4         1.225615    16.793382           84.629307      495.597821
#
#    Perihelion Distance  Perihelion Arg  Aphelion Dist  Perihelion Time  \
# 0             0.808259       57.257470       2.005764     2.458162e+06
# 1             0.718200      313.091975       1.497352     2.457795e+06
# 2             0.950791      248.415038       1.966857     2.458120e+06
# 3             0.983902       18.707701       1.527904     2.457902e+06
# 4             0.967687      158.263596       1.483543     2.457814e+06
#
#    Mean Anomaly  Mean Motion
# 0    264.837533     0.590551
# 1    173.741112     0.845330
# 2    292.893654     0.559371
# 3     68.741007     0.700277
# 4    135.142133     0.726395
#
# [5 rows x 35 columns]

# %%
# Hacemos el Split 70-30 para train-test
X_train, X_test, y_train, y_test = train_test_split(X_nasa, y_nasa, test_size=0.3, stratify = y_nasa, random_state=0)

# %%
# Creamos y entrenamos modelo
treeclf = DecisionTreeClassifier(max_depth=3, random_state=1) # maxima profundidad = 3
treeclf.fit(X_train, y_train) # entrenamos el árbol
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=1)

# %%
# Importamos la librería que necesitamos
# %pip install pydotplus
from sklearn.tree import export_graphviz
from IPython.display import Image
import pydotplus

# Visualizamos el árbol generado usando graphviz
dot_data = export_graphviz(treeclf, out_file=None,
                feature_names=X_nasa.columns,
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())
# Out:
# Requirement already satisfied: pydotplus in c:\users\leand\appdata\local\programs\python\python313\lib\site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\leand\appdata\local\programs\python\python313\lib\site-packages (from pydotplus) (3.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
y_pred_tc = treeclf.predict(X_test)

#Exactitud del modelo
print('Exactitud (accuracy) del modelo: {:.2f} %'.format(accuracy_score(y_test, y_pred_tc)*100))
print("-"*100)

# Reporte del clasificador
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_tc))
# Out:
# Exactitud (accuracy) del modelo: 99.36 %
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1180
#         True       0.98      0.98      0.98       227
#
#     accuracy                           0.99      1407
#    macro avg       0.99      0.99      0.99      1407
# weighted avg       0.99      0.99      0.99      1407

# %% [markdown]
# # Comparamos por curva ROC con naive bayes

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB

bayes_multi = MultinomialNB()
bayes_multi.fit(X_train, y_train)
y_pred_nb = bayes_multi.predict(X_test)

# %%
def graficarCurvaRoc( y_pred, model ):
  fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred)
  auc = metrics.roc_auc_score(y_test, y_pred)
  # Graficamos
  plt.plot(fpr,tpr,label= model +" AUC="+str(round(auc,4))) #,label= "AUC="+str(auc))
  plt.legend(loc=4, fontsize=12)
  return auc

# Inicializamos los labels del gráfico
plt.figure(figsize=(20, 10))
plt.xlabel('% Not Hazardous', fontsize=14)
plt.ylabel('% Hazardous', fontsize=14)

# Graficamos la recta del azar
it = [i/100 for i in range(100)]
plt.plot(it,it,label="AZAR AUC=0.5",color="black")

modelos = {'bayesMulti':y_pred_nb, 'arbol':y_pred_tc }
for pred in modelos:
    auc = graficarCurvaRoc( modelos[pred] , pred )

# Agregamos el titulo y configuro el tamaño de letra
plt.title("Curva ROC", fontsize=14)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# # Ejercicio
# - ¿Cómo se compara el performance del arbol con Naive bayes en este dataset?
# - usando treeclf.feature_importances_ podemos ver la importancia de cada una de las columnas de X para el modelo, ¿que sucede con los arboles con menor profundidad?
# - ¿Cual es la diferencia entre los hiperparametros min_samples_split y min_samples_leaf?
# - ¿Como se compara la performance de un arbol de profundidad 1, 3 o 10?
# - ¿Afectará al modelo si escalamos las variables?

# %% [markdown]
# Implementar un modelo de bosque aleatoreo ([random forest](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)) y comparar su curva ROC

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, RocCurveDisplay, confusion_matrix, classification_report, ConfusionMatrixDisplay, accuracy_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Entrenar el Random Forest

# %%
rf = RandomForestClassifier(
    n_estimators=100,      # puedes ajustar el número de árboles
    max_depth=None,        # sin límite de profundidad
    random_state=0,
    n_jobs=-1              # para paralelizar si tu máquina lo permite
)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=0)

# %% [markdown]
# Obtener probabilidades de predicción

# %%
y_proba_rf = rf.predict_proba(X_test)[:, 1]

# %% [markdown]
# Calcular AUC‑ROC

# %%
auc_rf = roc_auc_score(y_test, y_proba_rf)
print(f"AUC‑ROC Random Forest: {auc_rf:.3f}")
# Out:
# AUC‑ROC Random Forest: 0.998

# %% [markdown]
# ROC del Random Forest

# %%
RocCurveDisplay.from_estimator(rf, X_test, y_test, name=f"RF (AUC = {auc_rf:.3f})")

plt.plot([0, 1], [0, 1], "k--", label="Aleatorio (AUC = 0.5)")
plt.title("Curva ROC: Random Forest vs. Otros Modelos")
plt.xlabel("Tasa de Falsos Positivos")
plt.ylabel("Tasa de Verdaderos Positivos")
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X_nasa, y_nasa, random_state=3, test_size=0.3)
model = RandomForestClassifier(max_depth=6)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %% [markdown]
# Initializamos clf_list como una lista vacia

# %%
clf_list = []

cm = confusion_matrix(y_test, y_pred)
cm = np.rot90(cm, 2)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.flip(model.classes_))
fig, ax = plt.subplots(figsize=(4,4))
disp.plot(ax=ax)
print(classification_report(y_test, y_pred))
clf_list.append(model)
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1182
#         True       1.00      0.98      0.99       225
#
#     accuracy                           1.00      1407
#    macro avg       1.00      0.99      0.99      1407
# weighted avg       1.00      1.00      1.00      1407

# %% [markdown]
# Inicializamos los labels del gráfico

# %%
plt.figure(figsize=(20, 10))
plt.xlabel('% Not Hazardous', fontsize=14)
plt.ylabel('% Hazardous', fontsize=14)
# Out:
# Text(0, 0.5, '% Hazardous')

# %% [markdown]
# Graficamos la recta del azar

# %%
it = [i/100 for i in range(100)]
plt.plot(it,it,label="AZAR AUC=0.5",color="black")

modelos_2 = {'bosque':y_pred, 'arbol':y_pred_tc }
for pred in modelos_2:
    auc = graficarCurvaRoc( modelos_2[pred] , pred )

# %% [markdown]
# Agregamos el titulo y configuro el tamaño de letra

# %%
plt.title("Curva ROC", fontsize=14)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# ## Punto 1)
# ¿Cómo se compara el performance del arbol con Naive bayes en este dataset?

# %% [markdown]
# Segun la curva ROC la performance del arbol es mejor.

# %% [markdown]
# ## Punto 2)
# usando treeclf.feature_importances_ podemos ver la importancia de cada una de las columnas de X para el modelo, ¿que sucede con los arboles con menor profundidad?

# %%
treeclf = DecisionTreeClassifier(max_depth=3)  # o cualquier otro árbol
treeclf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %% [markdown]
# Obtenés las importancias

# %%
importancias = treeclf.feature_importances_

# %% [markdown]
# Las ponés en un DataFrame con los nombres de las columnas

# %%
importancias_df = pd.DataFrame({
    'Variable': X_train.columns,
    'Importancia': importancias
})

# %% [markdown]
# Ordenás de mayor a menor

# %%
importancias_df = importancias_df.sort_values(by='Importancia', ascending=False)
print(importancias_df)
# Out:
#                         Variable  Importancia
# 6              Est Dia in M(max)     0.810396
# 21    Minimum Orbit Intersection     0.185589
# 8          Est Dia in Miles(max)     0.004015
# 2             Absolute Magnitude     0.000000
# 1                           Name     0.000000
# 0               Neo Reference ID     0.000000
# 4             Est Dia in KM(max)     0.000000
# 5              Est Dia in M(min)     0.000000
# 7          Est Dia in Miles(min)     0.000000
# 9           Est Dia in Feet(min)     0.000000
# 3             Est Dia in KM(min)     0.000000
# 11     Epoch Date Close Approach     0.000000
# 12  Relative Velocity km per sec     0.000000
# 13   Relative Velocity km per hr     0.000000
# 14                Miles per hour     0.000000
# 15      Miss Dist.(Astronomical)     0.000000
# 16             Miss Dist.(lunar)     0.000000
# 17        Miss Dist.(kilometers)     0.000000
# 10          Est Dia in Feet(max)     0.000000
# 18             Miss Dist.(miles)     0.000000
# 19                      Orbit ID     0.000000
# 20            Orbit Uncertainity     0.000000
# 22   Jupiter Tisserand Invariant     0.000000
# 23              Epoch Osculation     0.000000
# 24                  Eccentricity     0.000000
# 25               Semi Major Axis     0.000000
# 26                   Inclination     0.000000
# 27            Asc Node Longitude     0.000000
# 28                Orbital Period     0.000000
# 29           Perihelion Distance     0.000000
# 30                Perihelion Arg     0.000000
# 31                 Aphelion Dist     0.000000
# 32               Perihelion Time     0.000000
# 33                  Mean Anomaly     0.000000
# 34                   Mean Motion     0.000000

# %% [markdown]
# Los de menos profudnidad tienen en cuenta menos variables. A mas profundidad tienen en cuenta mas variables

# %% [markdown]
# ## Punto 3)
# ¿Cual es la diferencia entre los hiperparametros min_samples_split y min_samples_leaf?

# %% [markdown]
# El hiperparámetro min_samples_split controla el número mínimo de muestras requerido para dividir un nodo, mientras que min_samples_leaf establece cuántas muestras como mínimo debe contener una hoja; ajustar estos valores permite regular la complejidad del árbol y reducir el riesgo de sobreajuste

# %% [markdown]
# ## Punto 4)
# ¿Como se compara la performance de un arbol de profundidad 1, 3 o 10?

# %% [markdown]
# Dividir datos

# %%
X_train, X_test, y_train, y_test = train_test_split(X_nasa, y_nasa, test_size=0.3, random_state=42)

# %% [markdown]
# Definir profundidades a comparar

# %%
depths = [1, 3, 10, 50]

for depth in depths:
    print(f"\nÁrbol con profundidad máxima = {depth}")

    # Crear y entrenar el árbol
    clf = DecisionTreeClassifier(max_depth=depth, random_state=42)
    clf.fit(X_train, y_train)

    # Predicciones
    y_train_pred = clf.predict(X_train)
    y_test_pred = clf.predict(X_test)

    # Accuracy
    train_acc = accuracy_score(y_train, y_train_pred)
    test_acc = accuracy_score(y_test, y_test_pred)

    print(f"Accuracy en entrenamiento: {train_acc:}")
    print(f"Accuracy en test: {test_acc:}")
# Out:
# Árbol con profundidad máxima = 1
# Accuracy en entrenamiento: 0.8347560975609756
# Accuracy en test: 0.8486140724946695
#
# Árbol con profundidad máxima = 3
# Accuracy en entrenamiento: 0.9960365853658537
# Accuracy en test: 0.9936034115138592
#
# Árbol con profundidad máxima = 10
# Accuracy en entrenamiento: 1.0
# Accuracy en test: 0.994314143567875
#
# Árbol con profundidad máxima = 50
# Accuracy en entrenamiento: 1.0
# Accuracy en test: 0.994314143567875

# %% [markdown]
# ## Punto 5)
# ¿Afectará al modelo si escalamos las variables?

# %% [markdown]
# No afecta escalar a este algoritmo

# %% [markdown]
# Dividir los datos

# %%
X_train, X_test, y_train, y_test = train_test_split(X_nasa, y_nasa, test_size=0.3, random_state=42)

# %% [markdown]
# Escalado

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Definir profundidades a comparar

# %%
depths = [1, 3, 10, 50]

for depth in depths:
    print(f"\nÁrbol con profundidad máxima = {depth}")

    # Crear y entrenar el árbol
    clf = DecisionTreeClassifier(max_depth=depth, random_state=42)
    clf.fit(X_train_scaled, y_train)

    # Predicciones
    y_train_pred = clf.predict(X_train_scaled)
    y_test_pred = clf.predict(X_test_scaled)

    # Accuracy
    train_acc = accuracy_score(y_train, y_train_pred)
    test_acc = accuracy_score(y_test, y_test_pred)

    print(f"Accuracy en entrenamiento: {train_acc:}")
    print(f"Accuracy en test: {test_acc:}")
# Out:
# Árbol con profundidad máxima = 1
# Accuracy en entrenamiento: 0.8347560975609756
# Accuracy en test: 0.8486140724946695
#
# Árbol con profundidad máxima = 3
# Accuracy en entrenamiento: 0.9960365853658537
# Accuracy en test: 0.9936034115138592
#
# Árbol con profundidad máxima = 10
# Accuracy en entrenamiento: 1.0
# Accuracy en test: 0.994314143567875
#
# Árbol con profundidad máxima = 50
# Accuracy en entrenamiento: 1.0
# Accuracy en test: 0.994314143567875
